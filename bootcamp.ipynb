# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijayvarma115/Data-Science-Gen-AI-Playlist-2024/blob/main/bootcamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np1=np.array([1,2,3,4])
print(np1)
print(type(np1))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
n=np.array([[1,2,3,4],[5,6,7,8]])

# %%
print(n)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
print(type(n))
n[1][1]=15
print(n)
# Out:
# <class 'numpy.ndarray'>
# [[ 1  2  3  4]
#  [ 5 15  7  8]]

# %%
print(len(n))
# Out:
# 2

# %%
r=np.zeros((3,3))
print(r)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
r=np.ones((3,3))
print(r)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
r=np.ones((3,3),dtype='int')
print(r)
# Out:
# [[1 1 1]
#  [1 1 1]
#  [1 1 1]]

# %%
r2=np.full((3,3),2)
print(r2)
# Out:
# [[2 2 2]
#  [2 2 2]
#  [2 2 2]]

# %% [markdown]
# Intro to PANDAS

# %%
import pandas as pd
import numpy as np

# %%
arr=np.array([1,2,3,4,5])

# %%
dfs=pd.Series(arr)

# %%
dfs
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data={'Name':['Raj','Sheldon','Joey','Bharath','Vamsi','Soumya'],'Age':[19,17,22,23,43,45]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age
# 0      Raj   19
# 1  Sheldon   17
# 2     Joey   22
# 3  Bharath   23
# 4    Vamsi   43
# 5   Soumya   45

# %%
df.head()#printing 1st 5 values or rows?
# Out:
#       Name  Age
# 0      Raj   19
# 1  Sheldon   17
# 2     Joey   22
# 3  Bharath   23
# 4    Vamsi   43

# %%
df.tail()#last 5 rows
# Out:
#       Name  Age
# 1  Sheldon   17
# 2     Joey   22
# 3  Bharath   23
# 4    Vamsi   43
# 5   Soumya   45

# %%
#if required customable rows
df.head(6)
# Out:
#       Name  Age
# 0      Raj   19
# 1  Sheldon   17
# 2     Joey   22
# 3  Bharath   23
# 4    Vamsi   43
# 5   Soumya   45

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   6.000000
# mean   28.166667
# std    12.464617
# min    17.000000
# 25%    19.750000
# 50%    22.500000
# 75%    38.000000
# max    45.000000

# %%
df[0:1]
# Out:
#   Name  Age
# 0  Raj   19

# %%
 df.iloc[0:1,0]
# Out:
# 0    Raj
# Name: Name, dtype: object

# %%
df['new']=[5,6,7,8,9,10]

# %%
df
# Out:
#       Name  Age  new
# 0      Raj   19    5
# 1  Sheldon   17    6
# 2     Joey   22    7
# 3  Bharath   23    8
# 4    Vamsi   43    9
# 5   Soumya   45   10

# %%
df.rename(columns={'new':'class'},inplace=1)

# %%
df
# Out:
#       Name  Age  class
# 0      Raj   19      5
# 1  Sheldon   17      6
# 2     Joey   22      7
# 3  Bharath   23      8
# 4    Vamsi   43      9
# 5   Soumya   45     10

# %%
df1=df

# %%
df1
# Out:
#       Name  Age  class
# 0      Raj   19      5
# 1  Sheldon   17      6
# 2     Joey   22      7
# 3  Bharath   23      8
# 4    Vamsi   43      9
# 5   Soumya   45     10

# %%
df2=df.copy()

# %%
df2
# Out:
#       Name  Age  class
# 0      Raj   19      5
# 1  Sheldon   17      6
# 2     Joey   22      7
# 3  Bharath   23      8
# 4    Vamsi   43      9
# 5   Soumya   45     10

# %%
df=pd.read_csv('/content/spotify-2023.csv',encoding='latin1')

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df.head(10)
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
# 8                             fukumean                       Gunna
# 9                      La Bebe - Remix       Peso Pluma, Yng Lvcas
#
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# ...

# %%
df.tail(20)
# Out:
#                         track_name               artist(s)_name  artist_count  \
# 933                 Vigilante Shit                 Taylor Swift             1
# 934                   Question...?                 Taylor Swift             1
# 935                          On BS             Drake, 21 Savage             2
# 936                     Mastermind                 Taylor Swift             1
# 937                     Circo Loco             Drake, 21 Savage             2
# 938                      Labyrinth                 Taylor Swift             1
# 939                    Spin Bout U             Drake, 21 Savage             2
# 940                  Sweet Nothing                 Taylor Swift             1
# 941  Would've, Could've, Should've                 Taylor Swift             1
# 942                   Con La Brisa  Ludwig Goransson, Foudeqush             2
# 943             Privileged Rappers             Drake, 21 Savage             2
# ...

# %%
df.shape
# Out:
# (953, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
df.isnull()
# Out:
#      track_name  artist(s)_name  artist_count  released_year  released_month  \
# 0         False           False         False          False           False
# 1         False           False         False          False           False
# 2         False           False         False          False           False
# 3         False           False         False          False           False
# 4         False           False         False          False           False
# ..          ...             ...           ...            ...             ...
# 948       False           False         False          False           False
# 949       False           False         False          False           False
# 950       False           False         False          False           False
# 951       False           False         False          False           False
# 952       False           False         False          False           False
#
# ...

# %%
df.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# in_shazam_charts        0
# bpm                     0
# key                     0
# mode                    0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# dtype: int64

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams   mode  danceability_%  energy_%
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'mode', 'danceability_%', 'energy_%'],
#       dtype='object')

# %%
# df.drop(['in_apple_playlists','in_apple_charts','in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key','instrumentalness_%','acousticness_%','liveness_%', 'speechiness_%', 'valence_%'],axis=1)

# %%
pd.DataFrame(df['artist(s)_name'].str.split(' , ').sum()).value_counts()
# Out:
# Taylor Swift                          29
# SZA                                   17
# Bad Bunny                             16
# The Weeknd                            15
# Harry Styles                          12
#                                       ..
# J Balvin, Bad Bunny                    1
# Israel & Rodolffo, Mari Fernandez      1
# Israel & Rodolffo, Ana Castela         1
# Intense, AP Dhillon, Gurinder Gill     1
# teto                                   1
# Name: count, Length: 571, dtype: int64

# %%
df.sort_values(by='streams',ascending=False)
# Out:
#                                   track_name      artist(s)_name  \
# 574      Love Grows (Where My Rosemary Goes)   Edison Lighthouse
# 33                                 Anti-Hero        Taylor Swift
# 253                            Glimpse of Us                Joji
# 455                           Seek & Destroy                 SZA
# 98                        Summertime Sadness        Lana Del Rey
# ..                                       ...                 ...
# 750                                  Falling        Harry Styles
# 366                                  Revenge        XXXTENTACION
# 744                                 Right On            Lil Baby
# 515                             Best Friends          The Weeknd
# 301  Arcï¿½ï¿½ngel: Bzrp Music Sessions, Vol  Arcangel, Bizarrap
#
#      artist_count  released_year  released_month  released_day  \
# 574             1           1970               1             1
# ...

# %%
df.sort_values(by='in_spotify_playlists',ascending=False)
# Out:
#                                      track_name  \
# 757                      Get Lucky - Radio Edit
# 630                              Mr. Brightside
# 720                     Wake Me Up - Radio Edit
# 624   Smells Like Teen Spirit - Remastered 2021
# 199                                  Take On Me
# ..                                          ...
# 104                                   New Jeans
# 185                                     Cheques
# 112                                     LAGUNAS
# 327  Peaches (from The Super Mario Bros. Movie)
# 94                               Still With You
#
#                                  artist(s)_name  artist_count  released_year  \
# 757  Pharrell Williams, Nile Rodgers, Daft Punk             3           2013
# 630                                 The Killers             1           2003
# 720                                      Avicii             1           2013
# ...

# %%
df.to_csv('final.csv')

# %%
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df.drop(['in_spotify_charts'],axis=1,inplace=True)

# %%
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df.to_csv('final.csv',index=False)

# %%
df.drop(['energy_%'],axis=1,inplace=True)

# %%
df.to_csv('final.csv')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
